# %%
from linkedlist import LinkedList

# %%
ll=LinkedList()
ll

# %%
ll.insert(0,1000)
ll.insert(0,500)
ll.print_list()
# Out:
# 500 -> 1000 -> None

# %%
ll.get(1)
# Out:
# 1000

# %%
ll.delete(1)
ll.print_list()
# Out:
# 500 -> None

# %%
ll.get(0)
# Out:
# 500
