# %%
#외부의 모둘을 로드 -> import 모듈 이름
import mod 
#from 라이브러리명 import 특정 모듈(클래스, 함수, 변수)
from mod import Bank

#from ~ import를 사용하는 이유?
#외부의 라이브러리에서 내가 사용하는 기능은 20%라 가정
#100%를 로드해서 20%를 사용한다 -> import lib
#100%에서 30%만 로드해서 20%만 사용한다 -> from lib import mod

# %%
#모듈(mod) 안에(.) 있는 변수(test_vari)를 호출
mod.test_vari
# Out:
# '모듈 안의 변수 데이터'

# %%
#모듈 안에 함수 호출
mod.func_1(10,4)
# Out:
# 14

# %%
#모듈 안에 클래스 생성
user1=mod.User('kim','000301',0)

# %%
user1.work('A',40)
# Out:
# 입금이 완료 되었습니다. 현재의 잔액은 880000입니다.

# %%
bank1=Bank('park','000101')
