# %% [markdown]
# ### 웹 크롤링
# - 라이브러리
#     - requests
#         - 웹 서버에 요청을 보내고 응답을 받는 기능
#         - 응답 데이터는 bytes, string형으로 들어온다.
#     - bs4
#         - BeautifulSoup class를 이용
#         - html로 이루어진 문자 데이터를 parsing작업을 통해서 데이터의 타입을 변경하여 내부의 데이터에 쉽게 접근하여 추출하기 위한 기능
#             - `"<html><body><p>Text</p></body></html>"` -> 태그를 기준으로 데이터에 접근할 수 있는 함수들이 존재
#         - 웹의 기본 구조를 파악하고 사용을 하면 조금 더 쉽게 접근 가능
#             - 태그 별 속성의 값
#             - 태그의 특징
#     - selenium
#         - 웹 어플리케이션을 테스트하기 위한 라이브러리
#         - 웹 브라우저(chrome, ...)를 python code를 이용하여 제어
#             - 함수를 이용해서 특정 버튼을 클릭
#             - 특정 위치에 데이터를 입력
#
#         - 구글 크롬의 버전이 구버전인 경우 별도의 소프트웨어를 설치가 필요
# - 데이터를 불법적으로 가지고 오는 방법(합법/위법 사이)
#     - 사이트들마다 크롤링이 가능한 주소들은 지정
#     - 상업적인 용도가 아닌 수업에서의 내용은 큰 지장은 없음

# %%
#라이브러리 설치
# !pip install bs4 selenium

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
#requests 라이브러리를 이용해서 openapi에서는 데이터의 결과물이 xml,json 형태
#https://www.naver.com 에 요청을 보냈을때 어떤 데이터를 줄 것인가?
res=requests.get('https://www.naver.com')
#requests.get() https 프로토콜을 이용헤서 요청을 보낼 때 에러기 발생하는 경우 -> http

# %%
res.content
# Out:
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x
# ...

# %%
res.text
# Out:
# '   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description
# ...

# %%
html_text=res.text

# %%
#문자열에서 특정 문자의 위치를 찾는 함수 : find()
html_text.find('네이버')
# Out:
# 378

# %%
html_text[378:410]
# Out:
# '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요'

# %%
#문자형으로 이루어진 html 문서를 BeautifulSoup class를 이용해서 객체 변환
#문자 데이터에서는 특정 영역의 content를 추출하기 어렵다.
#Beautiful에 내장된 함수를 이용해서 데이터를 추출하기 위해 class 생성시  데이터를 대입
soup=bs(html_text,'html.parser' )

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# - 태그의 이름을 기준으로 검색
#     - soup.태그명
#         - 해당 html 문서 안에서 해당 태그 중 첫번째 태그를 되돌려준다.
#         - 문자열 함수에서 find() 함수와 비슷힌 부분
#     - soup.태그명.string
#             - 첫번째 태그에서 콘텐츠(태그 안에 데이터)를 되돌려준다.
#                 - ex) `<p>Test</p>` --> 'Test'
#     - soup.태그명[속성명]
#         - 첫번째 태그에서 특정 속성의 값을 되돌려준다.
#             - ex) `<a href = 'https://www.naver.com'>네이버</a>` -> `https://www.naver.com`

# %%
soup.a
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
soup.a.string
# Out:
# '상단영역 바로가기'

# %%
soup.a['href']
# Out:
# '#topAsideButton'

# %% [markdown]
# - 내장 함수
#     - find()
#         - html 문서 안에서 특정 태그의 첫번째 정보를 출력
#         - find(속성명 = 속성값)
#             - 태그들 중 특정 속성애 특정한 값을 가진 첫번째 정보를 출력
#         - 함수의 결과값의 타입은 TAG데이터의 타입으로 되돌려준다.
#     - find_all()
#         - html 문서 안에서 특정 태그의 모든 정보를 출력
#         - limit 매개변수
#             - 찾는 태그의 개수를 지정
#         - 함수의 결과 값의 타입은 ResultSet 타입으로 되돌려준다.
#     - find(), find_all() 함수는 Tag 타입에서는 사용가능 // ResultSet에서는 사용이 불가능
#     - ResultSet 타입은 Tag데이터들이 모여있는 리스트의 형태와 흡사

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
type(soup.find('a'))
# Out:
# bs4.element.Tag

# %%
type(soup.find_all('a'))
# Out:
# bs4.element.ResultSet

# %%
soup.find('a')
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
soup.find_all('a')
# Out:
# [<a href="#topAsideButton"><span>상단영역 바로가기</span></a>,
#  <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a>,
#  <a href="#newsstand"><span>새소식 블록 바로가기</span></a>,
#  <a href="#shopping"><span>쇼핑 블록 바로가기</span></a>,
#  <a href="#feed"><span>관심사 블록 바로가기</span></a>,
#  <a href="#account"><span>MY 영역 바로가기</span></a>,
#  <a href="#widgetboard"><span>위젯 보드 바로가기</span></a>,
#  <a href="#viewSetting"><span>보기 설정 바로가기</span></a>]

# %%
a_tag=soup.find('a')

# %%
a_tag.find('span')
# Out:
# <span>상단영역 바로가기</span>

# %%
a_list=soup.find_all('a')

# %%
#ResulSet은 fid(),find_all() 함수 사용 불가 -> 에러 발생
a_list.find('span')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 #ResulSet은 fid(),find_all() 함수 사용 불가 -> 에러 발생
# ----> 2 a_list.find('span')
#
# File c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\bs4\element.py:3203, in ResultSet.__getattr__(self, key)
#    3201 def __getattr__(self, key: str) -> None:
#    3202     """Raise a helpful exception to explain a common code fix."""
# -> 3203     raise AttributeError(
#    3204         f"""ResultSet object has no attribute "{key}". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?"""
#    3205     )
#
# AttributeError: ResultSet object has no attribute "find". You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
#모든 a태그에서 모든 content를 추출하여 새로운 리스트로 생성
#a_list에 있는 첫번째 tag를 선택하여 .string을 이용하여 텍스트 추출(8번 반복)
#a_list는 타입이 ResultSet인데 for문에서 바로 사용이 가능할까?
a_datas=[]
for tag_data in a_list:
    # print(tag_data.string)
    # break
    a_datas.append(tag_data.string)
a_datas
# Out:
# ['상단영역 바로가기',
#  '서비스 메뉴 바로가기',
#  '새소식 블록 바로가기',
#  '쇼핑 블록 바로가기',
#  '관심사 블록 바로가기',
#  'MY 영역 바로가기',
#  '위젯 보드 바로가기',
#  '보기 설정 바로가기']

# %%
#map() = lambda
#python에서 기본 제공 map의 결과를 list로 변환
list(
    map(
        lambda x : x.sting,
        a_list
    )
)
# Out:
# [None, None, None, None, None, None, None, None]

# %%
[data.string for data in a_list]
# Out:
# ['상단영역 바로가기',
#  '서비스 메뉴 바로가기',
#  '새소식 블록 바로가기',
#  '쇼핑 블록 바로가기',
#  '관심사 블록 바로가기',
#  'MY 영역 바로가기',
#  '위젯 보드 바로가기',
#  '보기 설정 바로가기']

# %%
#네이버 증권 사이트 크롤링

#requests 라이브러리를 이용해서 html문서를 받는다.
result=requests.get('https://finance.naver.com/')
#응답 데이터를 문자형으로 변환 -> BeautifulSoup 파싱
soup = bs(result.text, 'html.parser')

# %%
soup
# Out:
# <html lang="ko">
# <head>
# <title>Npay 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="Npay 증권" name="apple-mobile-web-app-title">
# <meta content="Npay 증권" property="og:title">
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="https://finance.naver.com" property="og:url"/>
# <meta content="국내 해외 증시 지수, 시장지표, 뉴스, 증권사 리서치 등 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="Npay 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/imgstock/static.pc/20260406095636/css/finance_header.css" rel="stylesheet" type="text/css"/>
# ...

# %%
#html문서 안에서 태그명이 div이고 class의 속성의 값이 section_sise_top인 태그를 모두 찾아서 길이를 구하자.
len(
    soup.find_all(
        'div',
        attrs = {
            'class' : 'section_sise_top'
        }
    )
)
# Out:
# 1

# %%
#1개라면 find_all()이 아닌 find()를 이용해서 데이터 추출
div_data=soup.find(
    'div',
    attrs={
        'class' : 'section_sise_top'
    }
)

# %%
div_data
# Out:
# <div class="section_sise_top">
# <h2 class="h_type"><span>TOP 종목</span></h2>
# <!-- KRX, NXT 탭 -->
# <div class="area_tab_type">
# <ul class="top_tab_list">
# <!-- [D] 선택된 탭 'is_active' -->
# <li class="top_tab_item top_tab_krx is_active">
# <a class="top_tab_link" href="#" onclick="clickcr(this, 'top.krx', '', '', event);return false;">KRX</a>
# </li>
# <li class="top_tab_item top_tab_nxt">
# <a class="top_tab_link" href="#" onclick="clickcr(this, 'top.nxt', '', '', event);return false;">NXT</a>
# </li>
# </ul>
# <div class="text_nxt">
#                                 넥스트레이드(NXT)
#                                 <button class="buttton_tooltip" type="button">
# <span class="icon">
# <span class="blind">도움말</span>
# </span>
# </button>
# <div class="area_tooltip">
# <p>
# <strong>넥스트레이드(NXT)</strong>
#                                         넥스트레이드(NXT)란 대한민국
#                                         최초의 대체거래소(ATS,
#                                         Alternative Trading
# ...

# %%
#div_data에서 table 태그 중 class의 값이 tbl_home인 태그의 개수가 어떻게 되는가?
len(
    div_data.find_all(
        'table',
        attrs={
            'class':'tbl_home'
        }
    )
)
# Out:
# 8

# %%
#8개의 테이블을 모두 찾는다.
tables = div_data.find_all(
    'table',
    attrs={
        'class':'tbl_home'
    }
)

# %%
tables[0]
#thead는 테이블의 제목(columns 이름) -> 따로 추출하여 columns 사용
#tbody는 테이블의 데이터(values) -> 따로 추출하여 values 사용
# Out:
# <table class="tbl_home">
# <caption>거래상위 TOP 종목<span>종목명에 대한 현재가, 전일대비, 등락률로 구분되어 있습니다.</span></caption>
# <colgroup>
# <col width="40%"/>
# <col/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>181</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>
# <td>
# <em class="down">
# 				-5.24%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '2', event);">KODEX 인버스</a></th>
# <td>1,394</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 38</td>
# <td>
# <em class="down">
# 				-2.65%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# ...

# %%
#반복문에서 사용할 변수명을 그대로 이용하여 1차 작업(반복 실행 코드를 테스트)
table_data=tables[0]

# %%
#columns에서 사용할 데이터들을 추출 -> table 데이터에서 thead 태그를 추출
head_data=table_data.find('thead')

# %%
head_data
# Out:
# <thead>
# <tr>
# <th scope="col">종목명</th>
# <th scope="col">현재가</th>
# <th scope="col">전일대비</th>
# <th scope="col">등락률</th>
# </tr>
# </thead>

# %%
#head_data에서 th태그를 모두 찾는다.
th_list = head_data.find_all('th')
#각각 th태그에서 콘탠츠를 추출하여 리스트로 만든다
#콘텐츠를 추출하는 방법은 string // get_text()
#case1
cols=[]
for th in th_list:
    cols.append(th.string)
cols
# Out:
# ['종목명', '현재가', '전일대비', '등락률']

# %%
#case2
cols2=list(
    map(
        lambda x : x.string,
        th_list
    )
)

# %%
#case3
cols3=[th.string for th in th_list]
cols3
# Out:
# ['종목명', '현재가', '전일대비', '등락률']

# %%
#values에서 사용할 데이터들을 추출
body_data=table_data.find('tbody')
body_data
# Out:
# <tbody id="_topItems1">
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>181</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>
# <td>
# <em class="down">
# 				-5.24%
# 				</em>
# </td>
# </tr>
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=114800" onclick="clickcr(this, 'spe.slist', '114800', '2', event);">KODEX 인버스</a></th>
# <td>1,394</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 38</td>
# <td>
# <em class="down">
# 				-2.65%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# <th scope="row"><a href="/item/main.naver?code=462330" onclick="clickcr(this, 'spe.slist', '462330', '3', event);">KODEX 2차전지산업레버리지</a></th>
# <td>2,570</td>
# <td><em class="bu_p bu_pup"><span class="blind">상승</span></em> 415</td>
# <td>
# <em class="up">
# 				+19.26%
# 				</em>
# </td>
# </tr>
# <tr class="up">
# ...

# %%
#tr을 모두 찾는다.
tr_list = body_data.find_all(
    'tr'
)
len(tr_list)
# Out:
# 15

# %%
#첫번쩨 tr 뎅이터에서 value를 추출 -> 15번 반복
tr=tr_list[0]
tr
# Out:
# <tr class="down">
# <th scope="row"><a href="/item/main.naver?code=252670" onclick="clickcr(this, 'spe.slist', '252670', '1', event);">KODEX 200선물인버스2X</a></th>
# <td>181</td>
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>
# <td>
# <em class="down">
# 				-5.24%
# 				</em>
# </td>
# </tr>

# %%
#두개의 태그를 모두 찾는다?
row_list=tr.find_all(['th','td'])

# %%
#row_list에서 콘탠츠 데이터 추출 -> string, get_text()
#get_text() : 태그 안에 모든 콘텐츠를 추출
#string() : 콘텐츠 데이터가 한 군데에 존재할때 추출가능
row_list[2].get_text()
# Out:
# <td><em class="bu_p bu_pdn"><span class="blind">하락</span></em> 10</td>

# %%
value_data=[data.get_text().strip() for data in row_list ]
value_data
# Out:
# ['KODEX 200선물인버스2X', '181', '하락 10', '-5.24%']

# %%
values=[]

for tr in tr_list:
    row_list=tr.find_all(['th','td'])
    value_data=[data.get_text().strip() for data in row_list ]
    #value_data를 이용해서 2차원 데이터 values 생성
    values.append(value_data)

values
# Out:
# [['KODEX 200선물인버스2X', '181', '하락 10', '-5.24%'],
#  ['KODEX 인버스', '1,394', '하락 38', '-2.65%'],
#  ['KODEX 2차전지산업레버리지', '2,570', '상승 415', '+19.26%'],
#  ['대우건설', '32,850', '상승 4,750', '+16.90%'],
#  ['삼성 인버스 2X WTI원유 선물 ETN', '22', '보합', '0.00%'],
#  ['에스아이리소스', '291', '하락 8', '-2.68%'],
#  ['국일제지', '470', '상승 108', '+29.83%'],
#  ['파인텍', '2,040', '상승 467', '+29.69%'],
#  ['드림시큐리티', '3,800', '하락 80', '-2.06%'],
#  ['SGA솔루션즈', '1,168', '상승 122', '+11.66%'],
#  ['KEC', '1,418', '상승 195', '+15.94%'],
#  ['신성이엔지', '3,935', '상승 35', '+0.90%'],
#  ['씨아이에스', '16,310', '상승 3,760', '+29.96%'],
#  ['진원생명과학', '1,346', '상승 24', '+1.82%'],
#  ['TIGER 200선물인버스2X', '193', '하락 11', '-5.39%']]

# %%
import pandas as pd

# %%
pd.DataFrame(values, columns=cols, )
# Out:
#                        종목명     현재가      전일대비      등락률
# 0         KODEX 200선물인버스2X     181     하락 10   -5.24%
# 1                KODEX 인버스   1,394     하락 38   -2.65%
# 2         KODEX 2차전지산업레버리지   2,570    상승 415  +19.26%
# 3                     대우건설  32,850  상승 4,750  +16.90%
# 4   삼성 인버스 2X WTI원유 선물 ETN      22        보합    0.00%
# 5                  에스아이리소스     291      하락 8   -2.68%
# 6                     국일제지     470    상승 108  +29.83%
# 7                      파인텍   2,040    상승 467  +29.69%
# 8                   드림시큐리티   3,800     하락 80   -2.06%
# 9                  SGA솔루션즈   1,168    상승 122  +11.66%
# 10                     KEC   1,418    상승 195  +15.94%
# 11                   신성이엔지   3,935     상승 35   +0.90%
# 12                   씨아이에스  16,310  상승 3,760  +29.96%
# 13                  진원생명과학   1,346     상승 24   +1.82%
# 14        TIGER 200선물인버스2X     193     하락 11   -5.39%

# %%
#8개 테이블 중 1개 완성
#8번 반복을 하는 반복문을 생성 -> 각각의 데이터프레임이 생성 -> 각각 다른 전역 변수에 저장 (globals()["변수명"])

#전역 변수의 이름을 반복 실행할때마다 변경하기 위한 기본값
vari_num=1

for table_data in tables:
    #thead를 추출 -> colums 데이터를 추출하기 위해서
    head_data=table_data.find('thead')
    #thead 데이터에서 각각 콘텐츠 데이터를 추출하여 리스트화
    cols3=[th.string for th in th_list]

    #tbody를 추출
    body_data=table_data.find('tbody')
    #여러개의 행이 존재 -> tr_list를 생성
    tr_list = body_data.find_all('tr')
    #각각의 tr_data를 추출하여 콘텐츠 데이터를 리스트화하고 새로운 리스트에 추가
    values=[]
    
    for tr in tr_list:
        row_list=tr.find_all(['th','td'])
        value_data=[data.get_text().strip() for data in row_list ]
        #value_data를 이용해서 2차원 데이터 values 생성
        values.append(value_data)

    #데이터프레임을 생성하고 전역변수에 저장
    globals()[f'df{vari_num}']=pd.DataFrame(values,columns=cols)

    #vari_num을 1 증가시킨다.
    vari_num += 1

# %%
df1

# %%
df2

# %%
df3

# %%
df4

# %%
df5

# %%
df6

# %%
df7

# %%
df8

# %%
# !pip install html5lib
# Out:
# ...
#
#    ---------------------------------------- 0/2 [webencodings]
#    ---------------------------------------- 0/2 [webencodings]
#    ---------------------------------------- 0/2 [webencodings]
#    ---------------------------------------- 0/2 [webencodings]
#    ---------------------------------------- 0/2 [webencodings]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
# ...

# %%
res=requests.get('https://finance.naver.com')

# %%
type(str(div_data))
# Out:
# str

# %%
#html 문서 안에서 table안에 데이터를 크롤링을 하려면
#pandas 호출 
# pd.read_html('https://finance.naver.com') #unicode error
pd.read_html(str(div_data))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\io\html.py:794, in _LxmlFrameParser._build_doc(self)
#     793 try:
# --> 794     r = parse(self.io, parser=parser)
#     795 except OSError as err:
#
# File c:\Users\user\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\lxml\html\__init__.py:918, in parse(filename_or_url, parser, base_url, **kw)
#     917     parser = html_parser
# --> 918 return etree.parse(filename_or_url, parser, base_url=base_url, **kw)
#
# File src/lxml/etree.pyx:3716, in lxml.etree.parse()
# -> 3716 'Could not get source, probably due dynamically evaluated source code.'
#
# File src/lxml/parser.pxi:2041, in lxml.etree._parseDocument()
# -> 2041 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
